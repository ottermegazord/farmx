# %% [markdown]
# Load libraries and packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import numpy as np
import matplotlib
import itertools
import operator
from sklearn.linear_model import LinearRegression
import math

# %% [markdown]
# Load Data.gov.sg weather dataset

# %%
df = pd.read_hdf("/home/ottermegazord/PycharmProjects/funstuff/farmx/data/sg_weather.h5")

# %%
df.tail(20)
# Out:
#            timestamp station_id  temperature  humidity  wind_speed  \
# 27163525  1519204740       S102          NaN       NaN         NaN
# 27163526  1519204860       S102          NaN       NaN         NaN
# 27163527  1519204920       S102          NaN       NaN         NaN
# 27163528  1519204980       S102          NaN       NaN         NaN
# 27163529  1519205040       S102          NaN       NaN         NaN
# 27163530  1519205160       S102          NaN       NaN         NaN
# 27163531  1519205220       S102          NaN       NaN         NaN
# 27163532  1519205280       S102          NaN       NaN         NaN
# 27163533  1519205340       S102          NaN       NaN         NaN
# 27163534  1519205460       S102          NaN       NaN         NaN
# 27163535  1519205520       S102          NaN       NaN         NaN
# 27163536  1519205580       S102          NaN       NaN         NaN
# 27163537  1519205640       S102          NaN       NaN         NaN
# 27163538  1519205760       S102          NaN       NaN         NaN
# 27163539  1519205820       S102          NaN       NaN         NaN
# 27163540  1519205880       S102          NaN       NaN         NaN
# 27163541  1519205940       S102          NaN       NaN         NaN
# 27163542  1519206060       S102          NaN       NaN         NaN
# 27163543  1519206120       S102          NaN       NaN         NaN
# 27163544  1519206180       S102          NaN       NaN         NaN
#
#           wind_direction  rainfall
# 27163525            54.0       NaN
# 27163526            55.0       NaN
# 27163527            55.0       NaN
# 27163528            54.0       NaN
# 27163529            54.0       NaN
# 27163530            53.0       NaN
# 27163531            52.0       NaN
# 27163532            52.0       NaN
# 27163533            51.0       NaN
# 27163534            51.0       NaN
# 27163535            51.0       NaN
# 27163536            52.0       NaN
# 27163537            52.0       NaN
# 27163538            51.0       NaN
# 27163539            52.0       NaN
# 27163540            51.0       NaN
# 27163541            50.0       NaN
# 27163542            51.0       NaN
# 27163543            51.0       NaN
# 27163544            51.0       NaN

# %% [markdown]
# Extract Sembawang weather station

# %%
sembawang = (df[df['station_id'] == 'S122']).reset_index()

# %%
len(sembawang['timestamp'])
# Out:
# 1151501

# %% [markdown]
# View first 10 lines from dataset

# %%
sembawang.head(10)
# Out:
#    index   timestamp station_id  temperature  humidity  wind_speed  \
# 0     11  1462440840       S122         29.2       NaN         NaN
# 1     32  1462440900       S122         29.2       NaN         NaN
# 2     53  1462440960       S122         29.2       NaN         NaN
# 3     74  1462441020       S122         29.2       NaN         NaN
# 4     95  1462441080       S122         29.3       NaN         NaN
# 5    116  1462441140       S122         29.2       NaN         NaN
# 6    137  1462441200       S122         29.2       NaN         NaN
# 7    158  1462441260       S122         29.2       NaN         NaN
# 8    178  1462441320       S122         29.2       NaN         NaN
# 9    198  1462441380       S122         29.2       NaN         NaN
#
#    wind_direction  rainfall
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# 5             NaN       NaN
# 6             NaN       NaN
# 7             NaN       NaN
# 8             NaN       NaN
# 9             NaN       NaN

# %% [markdown]
# Convert posix time to UTC time

# %%
datetime.utcfromtimestamp(sembawang['timestamp'][0]).strftime('%Y-%m-%dT%H:%M:%SZ')
# Out:
# '2016-05-05T09:34:00Z'

# %%
def posix2utc(timestamp):
    return datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
sembawang['time'] = sembawang['timestamp'].apply(posix2utc)

# %%
sembawang.head(10)
# Out:
#    index   timestamp station_id  temperature  humidity  wind_speed  \
# 0     11  1462440840       S122         29.2       NaN         NaN
# 1     32  1462440900       S122         29.2       NaN         NaN
# 2     53  1462440960       S122         29.2       NaN         NaN
# 3     74  1462441020       S122         29.2       NaN         NaN
# 4     95  1462441080       S122         29.3       NaN         NaN
# 5    116  1462441140       S122         29.2       NaN         NaN
# 6    137  1462441200       S122         29.2       NaN         NaN
# 7    158  1462441260       S122         29.2       NaN         NaN
# 8    178  1462441320       S122         29.2       NaN         NaN
# 9    198  1462441380       S122         29.2       NaN         NaN
#
#    wind_direction  rainfall                  time
# 0             NaN       NaN  2016-05-05T09:34:00Z
# 1             NaN       NaN  2016-05-05T09:35:00Z
# 2             NaN       NaN  2016-05-05T09:36:00Z
# 3             NaN       NaN  2016-05-05T09:37:00Z
# 4             NaN       NaN  2016-05-05T09:38:00Z
# 5             NaN       NaN  2016-05-05T09:39:00Z
# 6             NaN       NaN  2016-05-05T09:40:00Z
# 7             NaN       NaN  2016-05-05T09:41:00Z
# 8             NaN       NaN  2016-05-05T09:42:00Z
# 9             NaN       NaN  2016-05-05T09:43:00Z

# %%
sembawang.isna().sum()
# Out:
# index                  0
# timestamp              0
# station_id             0
# temperature        29104
# humidity          591859
# wind_speed        320734
# wind_direction    312167
# rainfall          982984
# time                   0
# dtype: int64

# %%
def scale_plot_size(factor=1.5):
    import matplotlib as mpl
    default_dpi = mpl.rcParamsDefault['figure.dpi']
    mpl.rcParams['figure.dpi'] = default_dpi*factor

# %% [markdown]
# Isolate year, month ... from times

# %%
sembawang['year'] = pd.DatetimeIndex(sembawang['time']).year
sembawang['month'] = pd.DatetimeIndex(sembawang['time']).month
sembawang['day'] = pd.DatetimeIndex(sembawang['time']).day
sembawang['hour'] = pd.DatetimeIndex(sembawang['time']).day
sembawang['minute'] = pd.DatetimeIndex(sembawang['time']).day

# %%
print(sembawang.head(10))
# Out:
#    index   timestamp station_id  temperature  humidity  wind_speed  \
# 0     11  1462440840       S122         29.2       NaN         NaN
# 1     32  1462440900       S122         29.2       NaN         NaN
# 2     53  1462440960       S122         29.2       NaN         NaN
# 3     74  1462441020       S122         29.2       NaN         NaN
# 4     95  1462441080       S122         29.3       NaN         NaN
# 5    116  1462441140       S122         29.2       NaN         NaN
# 6    137  1462441200       S122         29.2       NaN         NaN
# 7    158  1462441260       S122         29.2       NaN         NaN
# 8    178  1462441320       S122         29.2       NaN         NaN
# 9    198  1462441380       S122         29.2       NaN         NaN
#
#    wind_direction  rainfall                  time  year  month  day  hour  \
# 0             NaN       NaN  2016-05-05T09:34:00Z  2016      5    5     5
# 1             NaN       NaN  2016-05-05T09:35:00Z  2016      5    5     5
# 2             NaN       NaN  2016-05-05T09:36:00Z  2016      5    5     5
# 3             NaN       NaN  2016-05-05T09:37:00Z  2016      5    5     5
# 4             NaN       NaN  2016-05-05T09:38:00Z  2016      5    5     5
# 5             NaN       NaN  2016-05-05T09:39:00Z  2016      5    5     5
# 6             NaN       NaN  2016-05-05T09:40:00Z  2016      5    5     5
# 7             NaN       NaN  2016-05-05T09:41:00Z  2016      5    5     5
# 8             NaN       NaN  2016-05-05T09:42:00Z  2016      5    5     5
# 9             NaN       NaN  2016-05-05T09:43:00Z  2016      5    5     5
#
#    minute
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
# 5       5
# 6       5
# 7       5
# 8       5
# 9       5

# %% [markdown]
# Upsample data to 10 min readings

# %% [markdown]
# Change index to DatimeIndex

# %%
sembawang.index = pd.to_datetime(sembawang.timestamp, unit='s')
sembawang =(sembawang[(sembawang['year'] == 2017)])
sembawang = (sembawang[(sembawang['month'].between(1, 10, inclusive=True))])

# %%
upsampledSembawang = sembawang.resample('10T').mean().ffill()

# %% [markdown]
# # Plot graphs of features

# %% [markdown]
# ## Plot of temperature against time

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['temperature'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Temperature (DegC)', fontsize=8)
plt.title('Temperature against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Temperature against time (Sembawang Station)')

# %%
upsampledSembawang.shape
# Out:
# (43776, 12)

# %% [markdown]
# ## Plot of humidity against time

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['humidity'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Humidity (%)', fontsize=8)
plt.title('Humidity against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Humidity against time (Sembawang Station)')

# %% [markdown]
# ## Plot of Wind Speed against time

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['wind_speed'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Windspeed (m/s)', fontsize=8)
plt.title('Windspeed against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Windspeed against time (Sembawang Station)')

# %% [markdown]
# ## Plot of Wind Direction against time

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['wind_direction'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Wind Direction', fontsize=8)
plt.title('Wind direction against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Wind direction against time (Sembawang Station)')

# %% [markdown]
# ## Plot of Rainfall against time

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['rainfall'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Rainfall', fontsize=8)
plt.title('Rainfall against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Rainfall against time (Sembawang Station)')

# %% [markdown]
# # Data imputation

# %% [markdown]
# ## Interpolation

# %% [markdown]
# ### Find all combinations of features

# %%
features = ['temperature', 'wind_speed', 'rainfall', 'humidity']
combinations = []
for subset in itertools.combinations(features, 2):
    combinations.append(subset)

# %%
upsampledSembawang.head(5)
# Out:
#                             index     timestamp  temperature  humidity  \
# timestamp
# 2017-01-01 00:00:00  6.462437e+06  1.483229e+09    26.077778       NaN
# 2017-01-01 00:10:00  6.462604e+06  1.483230e+09    26.490000       NaN
# 2017-01-01 00:20:00  6.462783e+06  1.483230e+09    26.590000       NaN
# 2017-01-01 00:30:00  6.462961e+06  1.483231e+09    26.710000       NaN
# 2017-01-01 00:40:00  6.463140e+06  1.483231e+09    26.600000       NaN
#
#                      wind_speed  wind_direction  rainfall    year  month  day  \
# timestamp
# 2017-01-01 00:00:00    2.377778           317.0       0.0  2017.0    1.0  1.0
# 2017-01-01 00:10:00    2.300000           322.9       0.0  2017.0    1.0  1.0
# 2017-01-01 00:20:00    2.980000           319.4       0.0  2017.0    1.0  1.0
# 2017-01-01 00:30:00    2.260000           302.3       0.0  2017.0    1.0  1.0
# 2017-01-01 00:40:00    2.230000           298.4       0.0  2017.0    1.0  1.0
#
#                      hour  minute
# timestamp
# 2017-01-01 00:00:00   1.0     1.0
# 2017-01-01 00:10:00   1.0     1.0
# 2017-01-01 00:20:00   1.0     1.0
# 2017-01-01 00:30:00   1.0     1.0
# 2017-01-01 00:40:00   1.0     1.0

# %%
upsampledSembawang.isna().sum()
# Out:
# index             0
# timestamp         0
# temperature       0
# humidity          7
# wind_speed        0
# wind_direction    0
# rainfall          0
# year              0
# month             0
# day               0
# hour              0
# minute            0
# dtype: int64

# %%
noNanSembawang = upsampledSembawang.dropna()

for combination in combinations:
    score = np.corrcoef(noNanSembawang[combination[0]], noNanSembawang[combination[1]])[0][1]
    print("Correlation (%s vs %s): %.5f" % (combination[0], combination[1], score))
# Out:
# Correlation (temperature vs wind_speed): 0.61179
# Correlation (temperature vs rainfall): -0.09473
# Correlation (temperature vs humidity): -0.87627
# Correlation (wind_speed vs rainfall): 0.06642
# Correlation (wind_speed vs humidity): -0.61650
# Correlation (rainfall vs humidity): 0.04455

# %%
clf = LinearRegression().fit(np.array(noNanSembawang['rainfall']).reshape(-1, 1), np.array(noNanSembawang['humidity']).reshape(-1, 1))

# %%
upsampledSembawang.isna().sum()
# ip_temp_Semb = upsampledSembawang['temperature'].fillna()
# clf.predict(np.array([27.2]).reshape(1,-1))
# Out:
# index             0
# timestamp         0
# temperature       0
# humidity          7
# wind_speed        0
# wind_direction    0
# rainfall          0
# year              0
# month             0
# day               0
# hour              0
# minute            0
# dtype: int64

# %%
def prediction(feature):
    if math.isnan(feature) == False:
        return clf.predict(np.array([feature]).reshape(1, -1))[0][0]

humidity_interpolate = upsampledSembawang['rainfall'].apply(prediction)

upsampledSembawang['humidity'] = upsampledSembawang['humidity'].fillna(humidity_interpolate)
upsampledSembawang.isna().sum()
# Out:
# index             0
# timestamp         0
# temperature       0
# humidity          0
# wind_speed        0
# wind_direction    0
# rainfall          0
# year              0
# month             0
# day               0
# hour              0
# minute            0
# dtype: int64

# %%
scale_plot_size(3.0)
ax = plt.axes()
plt.plot(upsampledSembawang.index, upsampledSembawang['humidity'], linewidth=0.2)
ax.xaxis.grid(True)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.setp(ax.get_xticklabels(), rotation=85, fontsize=8)
plt.xlabel('Datetime', fontsize=8)
plt.ylabel('Humidity (%))', fontsize=8)
plt.title('Humidity against time (Sembawang Station)', fontsize=8)
# Out:
# Text(0.5,1,'Humidity against time (Sembawang Station)')

# %%
upsampledSembawang.tail(10)
# Out:
#                             index     timestamp  temperature  humidity  \
# timestamp
# 2017-10-31 22:20:00  1.425195e+07  1.509489e+09    24.177778     100.6
# 2017-10-31 22:30:00  1.323418e+07  1.509489e+09    24.200000     100.6
# 2017-10-31 22:40:00  1.323434e+07  1.509490e+09    24.200000     100.6
# 2017-10-31 22:50:00  1.323449e+07  1.509490e+09    24.190000     100.6
# 2017-10-31 23:00:00  1.323465e+07  1.509491e+09    24.244444     100.6
# 2017-10-31 23:10:00  1.323480e+07  1.509492e+09    24.400000     100.6
# 2017-10-31 23:20:00  1.323496e+07  1.509492e+09    24.520000     100.6
# 2017-10-31 23:30:00  1.323512e+07  1.509493e+09    25.322222     100.6
# 2017-10-31 23:40:00  1.323528e+07  1.509493e+09    25.640000     100.6
# 2017-10-31 23:50:00  1.436637e+07  1.509494e+09    25.937500     100.6
#
#                      wind_speed  wind_direction  rainfall    year  month  \
# timestamp
# 2017-10-31 22:20:00    1.044444      243.333333       0.0  2017.0   10.0
# 2017-10-31 22:30:00    1.230000      273.900000       0.0  2017.0   10.0
# 2017-10-31 22:40:00    1.462500      300.625000       0.0  2017.0   10.0
# 2017-10-31 22:50:00    1.210000      310.900000       0.0  2017.0   10.0
# 2017-10-31 23:00:00    1.400000      290.888889       0.0  2017.0   10.0
# 2017-10-31 23:10:00    0.855556      310.666667       0.0  2017.0   10.0
# 2017-10-31 23:20:00    0.940000      261.200000       0.0  2017.0   10.0
# 2017-10-31 23:30:00    0.711111      286.333333       0.0  2017.0   10.0
# 2017-10-31 23:40:00    1.330000      299.800000       0.0  2017.0   10.0
# 2017-10-31 23:50:00    1.112500      173.375000       0.0  2017.0   10.0
#
#                       day  hour  minute
# timestamp
# 2017-10-31 22:20:00  31.0  31.0    31.0
# 2017-10-31 22:30:00  31.0  31.0    31.0
# 2017-10-31 22:40:00  31.0  31.0    31.0
# 2017-10-31 22:50:00  31.0  31.0    31.0
# 2017-10-31 23:00:00  31.0  31.0    31.0
# 2017-10-31 23:10:00  31.0  31.0    31.0
# 2017-10-31 23:20:00  31.0  31.0    31.0
# 2017-10-31 23:30:00  31.0  31.0    31.0
# 2017-10-31 23:40:00  31.0  31.0    31.0
# 2017-10-31 23:50:00  31.0  31.0    31.0

# %%
upsampledSembawang.to_hdf('data/2017_sembawang.h5', key = 'upsampledSembawang')
